# %% [markdown]
# # Heatmap of differentially expressed genes in an RNA-seq dataset
#
# This notebook follows closely to [this online tutorial](https://training.galaxyproject.org/training-material/topics/transcriptomics/tutorials/rna-seq-viz-with-heatmap2/tutorial.html#create-heatmap-of-top-de-genes).  The datasets are available [here](https://zenodo.org/record/2529926#.YwaRPfHMIas) and should be downloaded into the ```data``` directory (which you may have to create).
#
# *Note:* this Jupyter notebook was converted to an html file using the following command in a terminal :
#
# ```
# jupyter nbconvert --execute --to html heatmap.ipynb
# ```
# ___
# *Author : Aaron M Geller, Aug. 2022*

# %%
# Run this cell to create the data directory and download the sample data.
# On subsequent runs of this notebook, you can skip this step

import urllib
import os

directory = os.path.join(os.getcwd(), 'data')
if (not os.path.exists(directory)):
    os.mkdir(directory)
_ = urllib.request.urlretrieve('https://zenodo.org/record/2529926/files/heatmap_genes?download=1', 
                               os.path.join(directory, 'heatmap_genes.txt'))
_ = urllib.request.urlretrieve('https://zenodo.org/record/2529926/files/limma-voom_luminalpregnant-luminallactate?download=1', 
                               os.path.join(directory, 'limma-voom_luminalpregnant-luminallactate.tsv'))
_ = urllib.request.urlretrieve('https://zenodo.org/record/2529926/files/limma-voom_normalised_counts?download=1', 
                               os.path.join(directory, 'limma-voom_normalised_counts.tsv'))

# %%
# import the necessary libraries
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Read in the DE results data using [```pandas```](https://pandas.pydata.org/).

# %%
DE_results = pd.read_csv('data/limma-voom_luminalpregnant-luminallactate.tsv',sep='\t')
DE_results
# Out:
#        ENTREZID   SYMBOL                                           GENENAME  \
# 0         12992  Csn1s2b                             casein alpha s2-like B
# 1         13358  Slc25a1  solute carrier family 25 (mitochondrial carrie...
# 2         11941   Atp2b2       ATPase, Ca++ transporting, plasma membrane 2
# 3         20531  Slc34a2  solute carrier family 34 (sodium phosphate), m...
# 4        100705    Acacb                 acetyl-Coenzyme A carboxylase beta
# ...         ...      ...                                                ...
# 15799     20525   Slc2a1  solute carrier family 2 (facilitated glucose t...
# 15800    103836   Zfp692                            zinc finger protein 692
# 15801    170718    Idh3b             isocitrate dehydrogenase 3 (NAD+) beta
# 15802     71810   Ranbp3                              RAN binding protein 3
# 15803     19252    Dusp1                     dual specificity phosphatase 1
#
# ...

# %% [markdown]
# ## 2. Filter the results to only include the most significant genes.

# %% [markdown]
# ### 2.1. Set a threshold for ```adj.P.Val < 0.01``` and ```abs(logFC) > 0.58```.
#
# Note, these threshold values are simply taken from the [online tutorial](https://training.galaxyproject.org/training-material/topics/transcriptomics/tutorials/rna-seq-viz-with-heatmap2/tutorial.html#create-heatmap-of-top-de-genes) that we are following.  Your most appropriate threshold values may be different, depending on your research.

# %%
df = DE_results.loc[(DE_results['adj.P.Val'] < 0.01) & (abs(DE_results['logFC']) > 0.58)]

# %% [markdown]
# ### 2.2. Sort by ```P.Value``` (in ascending order).

# %%
df = df.sort_values('P.Value')

# %% [markdown]
# ### 2.3. Select the top 20 for the plot.

# %%
DE_results_sig = df.head(20)

DE_results_sig
# Out:
#     ENTREZID    SYMBOL                                           GENENAME  \
# 0      12992   Csn1s2b                             casein alpha s2-like B
# 1      13358   Slc25a1  solute carrier family 25 (mitochondrial carrie...
# 2      11941    Atp2b2       ATPase, Ca++ transporting, plasma membrane 2
# 3      20531   Slc34a2  solute carrier family 34 (sodium phosphate), m...
# 4     100705     Acacb                 acetyl-Coenzyme A carboxylase beta
# 5      13645       Egf                            epidermal growth factor
# 6     230810   Slc30a2  solute carrier family 30 (zinc transporter), m...
# 7      68801    Elovl5  ELOVL family member 5, elongation of long chai...
# 8      19659      Rbp1                retinol binding protein 1, cellular
# 9      26366  Ceacam10  carcinoembryonic antigen-related cell adhesion...
# 10     69219     Ddah1          dimethylarginine dimethylaminohydrolase 1
# 11     12683     Cidea  cell death-inducing DNA fragmentation factor, ...
# ...

# %% [markdown]
# ## 3. Read in the normalized counts data using [```pandas```](https://pandas.pydata.org/).

# %%
normalized_counts = pd.read_csv('data/limma-voom_normalised_counts.tsv',sep='\t')
normalized_counts
# Out:
#         ENTREZID  SYMBOL                                   GENENAME   MCL1.DG  \
# 0         497097    Xkr4          X-linked Kx blood group related 4  3.932532
# 1          20671   Sox17      SRY (sex determining region Y)-box 17  1.890808
# 2          27395  Mrpl15        mitochondrial ribosomal protein L15  3.429894
# 3          18777  Lypla1                        lysophospholipase 1  4.505933
# 4          21399   Tcea1  transcription elongation factor A (SII) 1  5.804007
# ...          ...     ...                                        ...       ...
# 15799  100861696     NaN                                        NaN  3.367987
# 15800  100862004     NaN                                        NaN  7.281673
# 15801  100861837     NaN                                        NaN  0.842599
# 15802  100861924     NaN                                        NaN  0.897565
# 15803     170942   Erdr1      erythroid differentiation regulator 1  4.137666
#
# ...

# %% [markdown]
# ## 4. Match the normalized counts to our ```DE_results_sig``` dataframe.
#
# We will use ```pandas.DataFrame.merge``` with the ```ENTREZID``` column.

# %%
DE_results_sig_counts = DE_results_sig.merge(normalized_counts, on = 'ENTREZID', suffixes = ['','_counts'])
DE_results_sig_counts.columns
# Out:
# Index(['ENTREZID', 'SYMBOL', 'GENENAME', 'logFC', 'AveExpr', 't', 'P.Value',
#        'adj.P.Val', 'SYMBOL_counts', 'GENENAME_counts', 'MCL1.DG', 'MCL1.DH',
#        'MCL1.DI', 'MCL1.DJ', 'MCL1.DK', 'MCL1.DL', 'MCL1.LA', 'MCL1.LB',
#        'MCL1.LC', 'MCL1.LD', 'MCL1.LE', 'MCL1.LF'],
#       dtype='object')

# %% [markdown]
# ## 5. Create a heatmap using [```seaborn```](https://seaborn.pydata.org/).
#
# The y-axis will show the ```SYMBOL``` values.  The x-axis will show the ```MCL.*``` column names.  The colors will be defined by the respective ```MCL.*``` values.

# %% [markdown]
# ### 5.1. Select only the columns that we want to show in the plot.

# %%
# create a mask that has values of True for the columns that have names with 'SYMBOL' and 'MCL1.''
mask = DE_results_sig_counts.columns.str.contains('SYMBOL|MCL1.')

# remove the 'SYMBOL_counts' column (from the normalized counts file). 
# Note: this is only necessary here because the 'SYMBOL' column exists in both data files 
#   (and I renamed the 'SYMBOL' column in the normalized counts file to be 'SYMBOL_counts' during the merge.) 
mask *= ~DE_results_sig_counts.columns.str.contains('SYMBOL_counts')

# apply the mask
df = DE_results_sig_counts.loc[:, mask]
df
# Out:
#       SYMBOL   MCL1.DG   MCL1.DH   MCL1.DI   MCL1.DJ   MCL1.DK   MCL1.DL  \
# 0    Csn1s2b -3.036547 -2.264422 -0.334841  0.015467  6.000618  5.805354
# 1    Slc25a1  4.881465  4.574209  4.407566  4.365098  4.983846  5.116211
# 2     Atp2b2 -1.451584 -0.968966 -2.301674 -2.139811  1.797468  1.156747
# 3    Slc34a2 -0.229192  0.615997  2.363016  1.962999  2.943408  3.218612
# 4      Acacb  2.860002  3.355632  3.068617  3.178834  3.540934  3.844546
# 5        Egf -0.889705 -1.079997 -1.237544 -1.351316  0.249264  0.171544
# 6    Slc30a2  0.950514  1.331429  0.925395  0.283400  0.861193  0.785652
# 7     Elovl5  5.705402  5.701887  6.012446  5.811738  6.333922  6.344328
# 8       Rbp1  7.720129  7.731602  7.024142  6.908304  5.968943  5.980475
# 9   Ceacam10 -3.036547 -2.916498 -0.403554 -1.511780  0.013196  0.229259
# 10     Ddah1 -0.417637 -0.679459 -1.006218 -0.044654  0.788130  0.579202
# 11     Cidea -1.320340 -2.264422  0.838807  1.142224  2.984868  2.761405
# ...

# %% [markdown]
# ### 5.2. Set the index of the dataframe to be the ```SYMBOL``` names.

# %%
df.set_index('SYMBOL', drop = True, inplace = True)
df.index.name = None # remove the name from the index so that it doesn't show as a label in the plot below
df
# Out:
#            MCL1.DG   MCL1.DH   MCL1.DI   MCL1.DJ   MCL1.DK   MCL1.DL  \
# Csn1s2b  -3.036547 -2.264422 -0.334841  0.015467  6.000618  5.805354
# Slc25a1   4.881465  4.574209  4.407566  4.365098  4.983846  5.116211
# Atp2b2   -1.451584 -0.968966 -2.301674 -2.139811  1.797468  1.156747
# Slc34a2  -0.229192  0.615997  2.363016  1.962999  2.943408  3.218612
# Acacb     2.860002  3.355632  3.068617  3.178834  3.540934  3.844546
# Egf      -0.889705 -1.079997 -1.237544 -1.351316  0.249264  0.171544
# Slc30a2   0.950514  1.331429  0.925395  0.283400  0.861193  0.785652
# Elovl5    5.705402  5.701887  6.012446  5.811738  6.333922  6.344328
# Rbp1      7.720129  7.731602  7.024142  6.908304  5.968943  5.980475
# Ceacam10 -3.036547 -2.916498 -0.403554 -1.511780  0.013196  0.229259
# Ddah1    -0.417637 -0.679459 -1.006218 -0.044654  0.788130  0.579202
# Cidea    -1.320340 -2.264422  0.838807  1.142224  2.984868  2.761405
# Pmvk      3.617578  3.828816  3.982046  4.050013  4.950750  4.722997
# ...

# %% [markdown]
# ### 5.3. (Optional) scale each row to go from -1 to 1.
#
# Note that this rescaling is done here to makes it easier to visually identify which cell-types show the same pattern of up or down regulation for specific sets of genes (regardless of the magnitude of change across genes).  This step may not be necessary for all data sets.  In particular, if it is important to compare the magnitudes of the change between different genes, this rescaling should be skipped.

# %%
# this will be easier if we transpose the dataframe first
tmp = df.transpose()
for c in tmp.columns:
    data = tmp[c]
    norm = 2.*(data - min(data))/(max(data) - min(data)) - 1
    tmp[c] = norm
df = tmp.transpose()
df
# Out:
#            MCL1.DG   MCL1.DH   MCL1.DI   MCL1.DJ   MCL1.DK   MCL1.DL  \
# Csn1s2b  -1.000000 -0.902264 -0.658018 -0.613676  0.143926  0.119209
# Slc25a1  -0.816212 -0.925572 -0.984884 -1.000000 -0.779772 -0.732660
# Atp2b2   -0.854309 -0.771596 -1.000000 -0.972259 -0.297476 -0.407285
# Slc34a2  -1.000000 -0.844381 -0.522715 -0.596367 -0.415852 -0.365180
# Acacb    -0.965093 -0.809504 -0.899604 -0.865005 -0.751334 -0.656024
# Egf      -0.880092 -0.929522 -0.970447 -1.000000 -0.584234 -0.604423
# Slc30a2  -0.819063 -0.715750 -0.825876 -1.000000 -0.843289 -0.863777
# Elovl5   -0.770604 -0.772375 -0.615895 -0.717025 -0.453914 -0.448671
# Rbp1      0.996162  1.000000  0.763331  0.724579  0.410332  0.414190
# Ceacam10 -1.000000 -0.976999 -0.495517 -0.707854 -0.415667 -0.374269
# Ddah1    -0.852167 -0.917929 -1.000000 -0.758486 -0.549317 -0.601793
# Cidea    -0.852123 -1.000000 -0.513924 -0.466398 -0.177774 -0.212776
# Pmvk     -1.000000 -0.882227 -0.796796 -0.758902 -0.256709 -0.383690
# ...

# %% [markdown]
# ### 5.4. Use ```seaborn```'s heatmap function.
#
# - Use a blue - white - red colormap, using the ```cmap``` keyword.  See [here](https://matplotlib.org/stable/tutorials/colors/colormaps.html) for available colormaps.
# - Set the limits for the colormap to be symmetric around zero, so that white is shown at zero, using the ```vmin``` and ```vmax``` keywords.
# - Add a label to the colorbar, using the ```cbar_kws``` keyword.
# - See other keyword options [here](https://seaborn.pydata.org/generated/seaborn.heatmap.html).

# %%
# create the figure (and display it in the notebook)
f, ax = plt.subplots(figsize = [6,4])         
fs = sns.heatmap(df, cmap = 'bwr', vmin = -1, vmax = 1, cbar_kws = {'label': 'Renormalized Counts'}, ax = ax)

# (optional) rotate the x tick labels by 45 degrees
fs.set_xticklabels(fs.get_xticklabels(), rotation = 45)

# save the figure to a png file
f.figure.savefig('DE_heatmap.png', bbox_inches = 'tight', dpi = 100)

# %% [markdown]
# ## Relevant documentation links:
# - [pandas](https://pandas.pydata.org/)
# - [pandas.read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html),
# - [pandas.DataFrame.loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)
# - [pandas.DataFrame.sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)
# - [pandas.DataFrame.merge](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)
# - [pandas.DataFrame.set_index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html)
# - [pandas.DataFrame.transpose](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html)
# - [pandas.Series.str](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.html)
# - [seaborn](https://seaborn.pydata.org/)
# - [seaborn.heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
