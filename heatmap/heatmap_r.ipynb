# %% [markdown]
# # Heatmap of differentially expressed genes in an RNA-seq dataset
#
# This notebook follows closely to [this online tutorial](https://training.galaxyproject.org/training-material/topics/transcriptomics/tutorials/rna-seq-viz-with-heatmap2/tutorial.html#create-heatmap-of-top-de-genes).  The datasets are available [here](https://zenodo.org/record/2529926#.YwaRPfHMIas) and should be downloaded into the ```data/heatmap``` directory (which you may have to create).
#
#
# *Note:* this Jupyter notebook was converted to an R markdown file and then an html file using the following command in R :
#
# ```
# rmarkdown::convert_ipynb('heatmap_r.ipynb')
# rmarkdown::render('heatmap_r.Rmd')
# ```
#
# ___
# *Author : Aaron M Geller, Aug. 2022*

# %%
# Run this cell to create the data directory and download the sample data.
# On subsequent runs of this notebook, you can skip this step

directory = file.path(getwd(), 'data','heatmap')
dir.create(directory)

download.file('https://zenodo.org/record/2529926/files/heatmap_genes?download=1', 
    file.path(directory, 'heatmap_genes.txt'))
download.file('https://zenodo.org/record/2529926/files/limma-voom_luminalpregnant-luminallactate?download=1', 
    file.path(directory, 'limma-voom_luminalpregnant-luminallactate.tsv'))
download.file('https://zenodo.org/record/2529926/files/limma-voom_normalised_counts?download=1', 
    file.path(directory, 'limma-voom_normalised_counts.tsv'))
# Out:
# Warning message in dir.create(directory):
# "'C:\Users\ageller\NUIT\genomics\RCS_genomics_visualization\data\heatmap' already exists"

# %%
# import the necessary libraries
library(tidyr)
library(ggplot2)

# %% [markdown]
# ## 1. Read in the DE results data using [```read.delim```](https://www.rdocumentation.org/packages/utils/versions/3.6.2/topics/read.table).

# %%
DE_results <- read.delim('data/heatmap/limma-voom_luminalpregnant-luminallactate.tsv', sep='\t', header=TRUE)
head(DE_results)
# Out:
#   ENTREZID SYMBOL
# 1  12992   Csn1s2b
# 2  13358   Slc25a1
# 3  11941   Atp2b2
# 4  20531   Slc34a2
# 5 100705   Acacb
# 6  13645   Egf
#   GENENAME
# 1 casein alpha s2-like B
# 2 solute carrier family 25 (mitochondrial carrier, citrate transporter), member 1
# 3 ATPase, Ca++ transporting, plasma membrane 2
# 4 solute carrier family 34 (sodium phosphate), member 2
# 5 acetyl-Coenzyme A carboxylase beta
# 6 epidermal growth factor
#   logFC     AveExpr   t         P.Value      adj.P.Val
# 1 -8.603611 3.5629500 -43.79650 3.830650e-15 6.053959e-11
# 2 -4.124175 5.7796989 -29.90785 1.758595e-13 1.389642e-09
# 3 -7.386986 1.2821431 -27.81950 4.836363e-13 2.432800e-09
# 4 -4.177812 4.2786290 -27.07272 6.157428e-13 2.432800e-09
# 5 -4.314320 4.4409137 -25.22357 1.499977e-12 4.741129e-09
# 6 -5.362664 0.7359047 -24.59930 2.116244e-12 5.574188e-09

# %% [markdown]
# ## 2. Filter the results to only include the most significant genes.

# %% [markdown]
# ### 2.1. Set a threshold for ```adj.P.Val < 0.01``` and ```abs(logFC) > 0.58```.
#
# Note, these threshold values are simply taken from the [online tutorial](https://training.galaxyproject.org/training-material/topics/transcriptomics/tutorials/rna-seq-viz-with-heatmap2/tutorial.html#create-heatmap-of-top-de-genes) that we are following.  Your most appropriate threshold values may be different, depending on your research.

# %%
df <- DE_results[which(DE_results['adj.P.Val'] < 0.01 & abs(DE_results['logFC']) > 0.58),]

# %% [markdown]
# ### 2.2. Sort by ```P.Value``` (in ascending order).

# %%
df <- df[order(df$P.Value),]

# %% [markdown]
# ### 2.3. Select the top 20 for the plot.

# %%
DE_results_sig <- head(df, 20)

DE_results_sig
# Out:
#    ENTREZID SYMBOL
# 1   12992   Csn1s2b
# 2   13358   Slc25a1
# 3   11941   Atp2b2
# 4   20531   Slc34a2
# 5  100705   Acacb
# 6   13645   Egf
# 7  230810   Slc30a2
# 8   68801   Elovl5
# 9   19659   Rbp1
# 10  26366   Ceacam10
# 11  69219   Ddah1
# 12  12683   Cidea
# 13  68603   Pmvk
# 14  20440   St6gal1
# 15  19041   Ppl
# 16 170439   Elovl6
# 17  14598   Ggt1
# 18  67547   Slc39a8
# 19  72027   Slc39a4
# 20  20249   Scd1
#    GENENAME
# 1  casein alpha s2-like B
# 2  solute carrier family 25 (mitochondrial carrier, citrate transporter), member 1
# 3  ATPase, Ca++ transporting, plasma membrane 2
# 4  solute carrier family 34 (sodium phosphate), member 2
# 5  acetyl-Coenzyme A carboxylase beta
# 6  epidermal growth factor
# 7  solute carrier family 30 (zinc transporter), member 2
# 8  ELOVL family member 5, elongation of long chain fatty acids (yeast)
# 9  retinol binding protein 1, cellular
# 10 carcinoembryonic antigen-related cell adhesion molecule 10
# 11 dimethylarginine dimethylaminohydrolase 1
# 12 cell death-inducing DNA fragmentation factor, alpha subunit-like effector A
# 13 phosphomevalonate kinase
# 14 beta galactoside alpha 2,6 sialyltransferase 1
# 15 periplakin
# 16 ELOVL family member 6, elongation of long chain fatty acids (yeast)
# 17 gamma-glutamyltransferase 1
# 18 solute carrier family 39 (metal ion transporter), member 8
# 19 solute carrier family 39 (zinc transporter), member 4
# 20 stearoyl-Coenzyme A desaturase 1
#    logFC     AveExpr   t         P.Value      adj.P.Val
# 1  -8.603611 3.5629500 -43.79650 3.830650e-15 6.053959e-11
# 2  -4.124175 5.7796989 -29.90785 1.758595e-13 1.389642e-09
# 3  -7.386986 1.2821431 -27.81950 4.836363e-13 2.432800e-09
# 4  -4.177812 4.2786290 -27.07272 6.157428e-13 2.432800e-09
# 5  -4.314320 4.4409137 -25.22357 1.499977e-12 4.741129e-09
# 6  -5.362664 0.7359047 -24.59930 2.116244e-12 5.574188e-09
# 7  -3.203118 2.6958115 -23.80428 3.024668e-12 6.828836e-09
# 8  -2.863304 6.4552045 -22.35358 6.598744e-12 1.303582e-08
# 9   5.443044 6.1070332  21.05236 1.479143e-11 2.364746e-08
# 10 -3.295621 1.8210142 -20.93927 1.496296e-11 2.364746e-08
# 11 -6.264983 1.1766693 -20.86711 1.696231e-11 2.437021e-08
# 12 -4.840655 3.3749575 -23.34753 2.757732e-11 3.631933e-08
# 13 -2.676983 4.7231068 -19.59665 3.376092e-11 3.985063e-08
# 14 -2.847276 5.9159772 -19.52868 3.530175e-11 3.985063e-08
# 15  3.609831 6.3870283  19.37314 3.942991e-11 3.994798e-08
# 16 -3.181536 5.0326036 -19.32178 4.044341e-11 3.994798e-08
# 17 -3.018192 6.0957539 -18.85092 5.472729e-11 5.087706e-08
# 18 -6.575426 3.4057103 -18.53671 7.427548e-11 6.521387e-08
# 19  4.362021 2.7487898  18.28949 8.167930e-11 6.793998e-08
# 20 -3.296577 9.1109538 -18.08614 9.155093e-11 7.234355e-08

# %% [markdown]
# ## 3. Read in the normalized counts data using [```read.delim```](https://www.rdocumentation.org/packages/utils/versions/3.6.2/topics/read.table).

# %%
normalized_counts = read.delim('data/heatmap/limma-voom_normalised_counts.tsv', sep='\t', header=TRUE)
head(normalized_counts)
# Out:
#   ENTREZID SYMBOL GENENAME                                  MCL1.DG   MCL1.DH
# 1 497097   Xkr4   X-linked Kx blood group related 4          3.932532  3.507368
# 2  20671   Sox17  SRY (sex determining region Y)-box 17      1.890808  2.787899
# 3  27395   Mrpl15 mitochondrial ribosomal protein L15        3.429894  3.149591
# 4  18777   Lypla1 lysophospholipase 1                        4.505933  4.285975
# 5  21399   Tcea1  transcription elongation factor A (SII) 1  5.804007  5.822559
# 6  58175   Rgs20  regulator of G-protein signaling 20       -2.673976 -3.401925
#   MCL1.DI    MCL1.DJ   MCL1.DK    MCL1.DL   MCL1.LA    MCL1.LB    MCL1.LC
# 1  1.2723173  3.292541  3.9909851  3.724252 -5.8019424 -5.8887821 -5.4816421
# 2  1.6052165  2.121856  0.9642868  1.923156 -0.7575483 -0.2163568 -0.2721888
# 3  3.6376380  3.631978  3.7037376  3.636318  4.3286281  3.9707527  4.4535229
# 4  5.1283983  5.270351  5.3801014  5.185279  4.8889286  4.8635986  4.9031416
# 5  5.9883448  5.764344  5.7006304  5.615502  5.5801412  5.4087074  5.5797290
# 6 -0.9031247 -2.429318 -3.1567286 -3.121238  2.6116855  2.4819053  2.6321000
#   MCL1.LD   MCL1.LE   MCL1.LF
# 1 -5.343143 -4.709206 -4.7226146
# 2 -1.255680 -1.901851 -0.3302972
# 3  4.016606  4.555237  4.6973455
# 4  4.993363  5.379583  5.4610208
# 5  5.512504  5.280898  5.2446116
# 6  1.575720  1.072154  0.2315817

# %% [markdown]
# ## 4. Match the normalized counts to our ```DE_results_sig``` dataframe.
#
# We will use ```merge``` with the ```ENTREZID``` column.

# %%
DE_results_sig$id <- 1:nrow(DE_results_sig) # so that we can keep the same order (for the plot as well)
DE_results_sig_counts <- merge(DE_results_sig, normalized_counts, by = 'ENTREZID', suffixes = c('','_counts'), all.x = TRUE)
DE_results_sig_counts <- DE_results_sig_counts[order(DE_results_sig_counts$id), ]
DE_results_sig_counts
# Out:
#    ENTREZID SYMBOL
# 3   12992   Csn1s2b
# 16  0.04195524  0.2997176  0.8856754  6.956574  6.737329
# 2   2.41955693  5.2707385  5.9520516 10.390430 10.504061
# 14  4.10698506  4.5027763  4.4818154  7.134323  7.204793
# 10  3.45329257  6.9548091  7.0707490  9.810738  9.909301
# 7   7.73201048  8.2271184  8.4374990  4.646145  4.798986
# 19  4.47206499  4.5777023  4.3451070  7.703629  7.588850
# 6   5.52643150  4.2239902  4.3416053  7.243899  7.354535
# 13  0.87940223  0.2997176  1.2862133  7.400951  7.298712
# 17  2.92820153  6.4729177  6.5268360  2.430346  1.847241
# 9   8.35372216 11.0385315 11.1454343 14.322832 14.454783

# %% [markdown]
# ## 5. Create a heatmap using [```ggplot2```](https://ggplot2.tidyverse.org/).
#
# The y-axis will show the ```SYMBOL``` values.  The x-axis will show the ```MCL.*``` column names.  The colors will be defined by the respective ```MCL.*``` values.

# %% [markdown]
# ### 5.1. Select only the columns that we want to show in the plot.

# %%
# create a mask that has values of True for the columns that have names with 'SYMBOL' and 'MCL1.''
mask <- grepl('MCL1.|SYMBOL', names(DE_results_sig_counts))

# remove the 'SYMBOL_counts' column (from the normalized counts file). 
# Note: this is only necessary here because the 'SYMBOL' column exists in both data files 
#   (and I renamed the 'SYMBOL' column in the normalized counts file to be 'SYMBOL_counts' during the merge.) 
mask <- mask & !grepl('SYMBOL_counts', names(DE_results_sig_counts))

# apply the mask
df <- DE_results_sig_counts[, mask]
df
# Out:
#    SYMBOL   MCL1.DG    MCL1.DH    MCL1.DI    MCL1.DJ     MCL1.DK
# 3  Csn1s2b  -3.0365466 -2.2644216 -0.3348410  0.01546680  6.00061829
# 4  Slc25a1   4.8814648  4.5742093  4.4075664  4.36509782  4.98384553
# 1  Atp2b2   -1.4515841 -0.9689657 -2.3016741 -2.13981143  1.79746766
# 11 Slc34a2  -0.2291917  0.6159968  2.3630156  1.96299938  2.94340803
# 18 Acacb     2.8600021  3.3556315  3.0686170  3.17883408  3.54093399
# 5  Egf      -0.8897052 -1.0799971 -1.2375437 -1.35131553  0.24926371
# 20 Slc30a2   0.9505144  1.3314292  0.9253948  0.28340000  0.86119326
# 15 Elovl5    5.7054019  5.7018872  6.0124456  5.81173822  6.33392170
# 8  Rbp1      7.7201289  7.7316024  7.0241424  6.90830386  5.96894312
# 12 Ceacam10 -3.0365466 -2.9164983 -0.4035537 -1.51178021  0.01319636
# 16 Ddah1    -0.4176367 -0.6794591 -1.0062182 -0.04465419  0.78812980
# 2  Cidea    -1.3203395 -2.2644216  0.8388071  1.14222394  2.98486763
# 14 Pmvk      3.6175779  3.8288159  3.9820457  4.05001313  4.95075000
# 10 St6gal1   5.6967109  5.7112961  5.0406027  4.79200054  4.24415079
# 7  Ppl       5.1022737  4.9009422  5.7550868  5.95102276  6.85141981
# 19 Elovl6    3.9937264  4.0023649  4.3408700  4.17059480  5.15706138
# 6  Ggt1      6.7323466  6.5560475  6.5588486  6.58656157  6.43759596
# Slc39a8   0.91230310  0.87940223  0.2997176  1.2862133  7.400951  7.298712
# Slc39a4   3.07150169  2.92820153  6.4729177  6.5268360  2.430346  1.847241
# Scd1      8.34693132  8.35372216 11.0385315 11.1454343 14.322832 14.454783

# %% [markdown]
# ### 5.3. (Optional) scale each row to go from -1 to 1.
#
# Note that this rescaling is done here to makes it easier to visually identify which cell-types show the same pattern of up or down regulation for specific sets of genes (regardless of the magnitude of change across genes).  This step may not be necessary for all data sets.  In particular, if it is important to compare the magnitudes of the change between different genes, this rescaling should be skipped.

# %%
library(data.table) # to use the transpose function

# %%
# this will be easier if we transpose the dataframe first

# transpose data frame
tmp <- transpose(df)

# redefine row and column names
rownames(tmp) <- colnames(df)
colnames(tmp) <- rownames(df)

# rescale each column 
for(i in 1:ncol(tmp)) {
    c <- colnames(tmp)[i]
    data <- tmp[c]
    norm <- 2.*(data - min(data))/(max(data) - min(data)) - 1 # normalize the data
    tmp[c] <- norm
}

df <- transpose(tmp)
# redefine row and column names
rownames(df) <- colnames(tmp)
colnames(df) <- rownames(tmp)
df
# Out:
#          MCL1.DG    MCL1.DH     MCL1.DI     MCL1.DJ      MCL1.DK
# Csn1s2b  -1.0000000 -0.90226428 -0.65801761 -0.613675593  0.143925968
# Slc25a1  -0.8162121 -0.92557199 -0.98488437 -1.000000000 -0.779772217
# Atp2b2   -0.8543088 -0.77159609 -1.00000000 -0.972259449 -0.297475702
# Slc34a2  -1.0000000 -0.84438141 -0.52271514 -0.596367308 -0.415851571
# Acacb    -0.9650927 -0.80950420 -0.89960409 -0.865004639 -0.751333873
# Egf      -0.8800923 -0.92952240 -0.97044668 -1.000000000 -0.584234070
# Slc30a2  -0.8190628 -0.71574976 -0.82587586 -1.000000000 -0.843288836
# Elovl5   -0.7706040 -0.77237488 -0.61589514 -0.717024715 -0.453914392
# Rbp1      0.9961617  1.00000000  0.76333129  0.724579472  0.410332315
# Ceacam10 -1.0000000 -0.97699867 -0.49551678 -0.707853729 -0.415667185
# Ddah1    -0.8521671 -0.91792852 -1.00000000 -0.758485732 -0.549316904
# Cidea    -0.8521231 -1.00000000 -0.51392364 -0.466397743 -0.177773988
# Pmvk     -1.0000000 -0.88222735 -0.79679627 -0.758902001 -0.256709152
# St6gal1  -0.3050138 -0.30049552 -0.50826892 -0.585283099 -0.755000884
# Ppl      -0.7593850 -0.86559060 -0.41501560 -0.311656214  0.163317721
# Elovl6   -1.0000000 -0.99534301 -0.81285570 -0.904650663 -0.372848750
# Ggt1      0.6025048  0.48987316  0.49166272  0.509367599  0.414198465
# Slc39a8  -0.1497894 -0.03405523 -0.03086872 -0.005975677  0.003684842
# Slc39a4  -0.1323310 -0.04139823 -0.29501344 -0.349274091 -1.000000000
# Scd1     -0.9434671 -1.00000000 -0.62139912 -0.725401213 -0.439343977
#          MCL1.DL    MCL1.LA     MCL1.LB     MCL1.LC     MCL1.LD     MCL1.LE
# Csn1s2b   0.1192094 -0.40479344 -0.47930625 -0.13444563 -0.04355501  1.0000000
# Slc25a1  -0.7326601 -0.77009408 -0.82078817 -0.52394478 -0.50792196  0.9037527
# Atp2b2   -0.4072846 -0.87186373 -0.79986214 -0.34724971 -0.24424404  0.9366198
# Slc34a2  -0.3651802 -0.35630108 -0.29182240  0.21472276  0.19223872  0.9455769
# Acacb    -0.6560237 -1.00000000 -0.83683627 -0.39629678 -0.37900986  0.9329700
# Egf      -0.6044226 -0.89418583 -0.84626996 -0.44503388 -0.33830614  1.0000000
# Slc30a2  -0.8637773 -0.62509763 -0.71603258  0.12050339  0.14128928  1.0000000
# Elovl5   -0.4486709 -0.97717402 -1.00000000 -0.52226073 -0.39909578  0.9633648
# Rbp1      0.4141901  0.44374027  0.49215193  0.99643336  0.94088426 -0.7034687
# Ceacam10 -0.3742694  0.24701381  0.16407805  0.37335016  0.35886017  0.9955470
# Ddah1    -0.6017930 -0.75243974 -0.73673220 -0.67199051 -0.52481656  1.0000000
# Cidea    -0.2127762 -0.36021669 -0.26632182  0.18027496  0.28699291  0.9822013
# Pmvk     -0.3836897 -0.73416033 -0.72713813 -0.50647042 -0.51815686  0.9607104
# St6gal1  -0.6507763 -0.91505725 -1.00000000  0.08473105  0.12064794  0.9694661
# Ppl       0.1793744  0.43158968  0.62784347  0.88902089  1.00000000 -1.0000000
# Elovl6   -0.3755282 -0.51834013 -0.74212876 -0.68517992 -0.81057153  1.0000000
# Ggt1      0.3863895 -0.38085674 -0.16791395 -1.00000000 -0.92485968  0.9293188
# Slc39a8   0.1294750 -0.82747068 -0.83673692 -1.00000000 -0.72216216  1.0000000
# Slc39a4  -0.9475147 -0.02835946 -0.07100774  0.98395310  1.00000000 -0.2191771
# Scd1     -0.4371794 -0.37811714 -0.37658492  0.22918973  0.25331027  0.9702278
#          MCL1.LF
# Csn1s2b   0.9973082
# Slc25a1   1.0000000
# Atp2b2    1.0000000
# Slc34a2   1.0000000
# Acacb     1.0000000
# Egf       0.9986213
# Slc30a2   0.9987270
# Elovl5    1.0000000
# Rbp1     -1.0000000
# Ceacam10  1.0000000
# Ddah1     0.9449326
# Cidea     1.0000000
# Pmvk      1.0000000
# St6gal1   1.0000000
# Ppl      -0.9193742
# Elovl6    0.9381230
# Ggt1      1.0000000
# Slc39a8   0.9712053
# Slc39a4  -0.3927179
# Scd1      1.0000000

# %% [markdown]
# ### 5.4. Use [```ggplot2```](https://ggplot2.tidyverse.org/)'s [```geom_tile```](https://ggplot2.tidyverse.org/reference/geom_tile.html) function to create the heatmap.
#
# - First we will need to reformat the data for ```ggplot```, using [```pivot_longer```](https://tidyr.tidyverse.org/reference/pivot_longer.html).
# - Define a colormap going from blue - white - red symmetric around zero using [```scale_fill_gradient2```](https://ggplot2.tidyverse.org/reference/scale_gradient.html).
# - Use [```guides```](https://ggplot2.tidyverse.org/reference/guides.html) and [```theme```](https://ggplot2.tidyverse.org/reference/theme.html) to set the formatting details of the plot.

# %%
# prepare data for ggplot

# add back the SYMBOL column (but only if you removed it above during rescaling)
df$SYMBOL <- rownames(df) 

# pivot_longer reformats the data table so ggplot can ingest it (see the format printed out below) 
df_long <- pivot_longer(
    data = df,
    cols = -c(SYMBOL),
    names_to = "measurement",
    values_to = "value"
)

# set the symbol type to be factor for ggplot
df_long$SYMBOL <- factor(df_long$SYMBOL, levels = unique(as.character(df_long$SYMBOL)))

head(df_long)
# Out:
#   SYMBOL  measurement value
# 1 Csn1s2b MCL1.DG     -1.0000000
# 2 Csn1s2b MCL1.DH     -0.9022643
# 3 Csn1s2b MCL1.DI     -0.6580176
# 4 Csn1s2b MCL1.DJ     -0.6136756
# 5 Csn1s2b MCL1.DK      0.1439260
# 6 Csn1s2b MCL1.DL      0.1192094

# %%
# for displaying in Jupyter
options(jupyter.plot_mimetypes = "image/png", repr.plot.width = 6, repr.plot.height = 4, repr.plot.res = 300)

heatmap_plot <- ggplot(data = df_long, aes(x = measurement, y = SYMBOL )) +
    geom_tile(aes(fill = value)) +
    scale_y_discrete(limits = rev) + # reverse the order on the y axis to match the order of the input dataframe
    scale_fill_gradient2( # define the colormap
        limits = c(-1,1),
        midpoint = 0,
        name = 'Renormalized Counts', 
        low = "#0000FF", 
        mid = "white", 
        high = "#FF0000"
    ) +
    guides( # to help position the colorbar
        fill = guide_colorbar(title.position = "right")
    ) +
    theme_classic() + # there are many themes to choose from : https://ggplot2.tidyverse.org/reference/ggtheme.html
    theme( # apply formatting
        axis.line = element_blank(), # remove the remaining axis lines
        axis.text.x = element_text(size = 10, angle = 45, vjust = 0.5), # increase the x axis text and rotate
        axis.text.y = element_text(size = 10),  # increase the y axis text
        legend.direction = "vertical",
        legend.key.height = unit(0.62, "in"), # increase the size of the legend (trying to make it the full size of the figure)
        legend.title = element_text(size = 12, angle = 90), # increase the legend text size and rotate it 90deg
        legend.title.align = 0.5, # center the legend title 
    ) +
    labs(x = '', y = '') # remove the axis titles

heatmap_plot

# save the figure to a png file
ggsave("DE_heatmap_r.png", width = 6, height = 4, dpi = 100)

# %% [markdown]
# ## Relevant documentation links:
# - [tidyr library](https://tidyr.tidyverse.org/)
# - [ggplot2 library](https://ggplot2.tidyverse.org/)
# - [data.table library](https://cran.r-project.org/web/packages/data.table/vignettes/datatable-intro.html)
# - [read.table (also including read.delim)](https://www.rdocumentation.org/packages/utils/versions/3.6.2/topics/read.table)
# - [pivot_longer](https://tidyr.tidyverse.org/reference/pivot_longer.html).
# - [geom_tile](https://ggplot2.tidyverse.org/reference/geom_tile.html)
# - [scale_fill_gradient2](https://ggplot2.tidyverse.org/reference/scale_gradient.html).
# - [guides](https://ggplot2.tidyverse.org/reference/guides.html)
# - [theme](https://ggplot2.tidyverse.org/reference/theme.html)
# - [available pre-made themes for ggplot2](https://ggplot2.tidyverse.org/reference/ggtheme.html)
